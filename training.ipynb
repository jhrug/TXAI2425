# %%
import importlib
import pickle

import keras_tuner as kt
import numpy as np
import tensorflow as tf
from tensorflow.keras import Input, Model, layers, callbacks
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight

import utils
importlib.reload(utils)

from utils import create_dataset, prepare_dataframe

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
DATASET_DIR = "datasets/utkface"
INPUT_SHAPE = (200, 200, 3)

FIXED_KERNEL_SIZE = (3, 3)
MIN_DENSE_UNITS = 16
NUM_AGE_CLASSES = 9

# %%
# Only process information for age class <= 8 (80-89) removing 200~ rows

df_full = prepare_dataframe(DATASET_DIR)
df = df_full[df_full['Age_Class'] <= 8].copy()

shuffled_df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df_full
# Out:
#                                               Image_Path  Age  Gender  \
# 0      datasets/utkface/100_0_0_20170112213500903.jpg...  100       0
# 1      datasets/utkface/100_0_0_20170112215240346.jpg...  100       0
# 2      datasets/utkface/100_1_0_20170110183726390.jpg...  100       1
# 3      datasets/utkface/100_1_0_20170112213001988.jpg...  100       1
# 4      datasets/utkface/100_1_0_20170112213303693.jpg...  100       1
# ...                                                  ...  ...     ...
# 23700  datasets/utkface/9_1_3_20161220222856346.jpg.c...    9       1
# 23701  datasets/utkface/9_1_3_20170104222949455.jpg.c...    9       1
# 23702  datasets/utkface/9_1_4_20170103200637399.jpg.c...    9       1
# 23703  datasets/utkface/9_1_4_20170103200814791.jpg.c...    9       1
# 23704  datasets/utkface/9_1_4_20170103213057382.jpg.c...    9       1
#
#        Ethnicity  Age_Class
# 0              0         10
# 1              0         10
# 2              0         10
# 3              0         10
# 4              0         10
# ...          ...        ...
# 23700          3          0
# 23701          3          0
# 23702          4          0
# 23703          4          0
# 23704          4          0
#
# [23705 rows x 5 columns]

# %%
shuffled_df
# Out:
#                                               Image_Path  Age  Gender  \
# 0      datasets/utkface/35_0_0_20170117191042138.jpg....   35       0
# 1      datasets/utkface/4_1_4_20161221193345109.jpg.c...    4       1
# 2      datasets/utkface/28_0_3_20170119211807137.jpg....   28       0
# 3      datasets/utkface/16_1_0_20170104013358122.jpg....   16       1
# 4      datasets/utkface/3_1_0_20170109194247387.jpg.c...    3       1
# ...                                                  ...  ...     ...
# 23531  datasets/utkface/32_1_0_20170117134737646.jpg....   32       1
# 23532  datasets/utkface/68_1_1_20170113012709282.jpg....   68       1
# 23533  datasets/utkface/25_1_1_20170112192328981.jpg....   25       1
# 23534  datasets/utkface/16_0_0_20170110232714508.jpg....   16       0
# 23535  datasets/utkface/40_1_2_20170116161936667.jpg....   40       1
#
#        Ethnicity  Age_Class
# 0              0          3
# 1              4          0
# 2              3          2
# 3              0          1
# 4              0          0
# ...          ...        ...
# 23531          0          3
# 23532          1          6
# 23533          1          2
# 23534          0          1
# 23535          2          4
#
# [23536 rows x 5 columns]

# %%
print(shuffled_df['Age_Class'].max()) # 8 is the biggest class
print(shuffled_df['Age_Class'].nunique()) # 9 total classes (0-8)
# Out:
# 8
# 9

# %%
# Train-test split, used for evaluating final model
df_train, df_test = train_test_split(shuffled_df, test_size=0.2, random_state=42)

# Train-val split, used for evaluating intermediate model
df_train_tune, df_val_tune = train_test_split(df_train, test_size=0.2, random_state=42)

# %%
classes =np.unique(df_train['Age_Class'])
print(f"Classes: {classes}")
weights = compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=df_train['Age_Class']
)
class_weight_dict = dict(zip(classes, weights))
print(f"Class weights calculated for tuner: {class_weight_dict}")
# Out:
# Classes: [0 1 2 3 4 5 6 7 8]
# Class weights calculated for tuner: {np.int64(0): np.float64(0.8528332653893193), np.int64(1): np.float64(1.711947626841244), np.int64(2): np.float64(0.35809654228004106), np.int64(3): np.float64(0.5709606986899564), np.int64(4): np.float64(1.1654596100278551), np.int64(5): np.float64(1.1526170798898072), np.int64(6): np.float64(1.9606373008434863), np.int64(7): np.float64(3.729055258467023), np.int64(8): np.float64(5.114914425427873)}

# %%
# Based on existing research found here: https://www.kaggle.com/datasets/jangedoo/utkface-new/code

class AgeHyperModel(kt.HyperModel):
    def __init__(self, use_class_weighting=False):
        self.use_class_weighting = use_class_weighting
    
    def build(self, hp):
        inputs = Input(shape=INPUT_SHAPE, dtype=tf.float32, name="input_image")
        
        hp_use_batch_norm = hp.Boolean("use_batch_norm_global", default=False)
        hp_bn_position = hp.Choice("bn_position", values=["before", "after"], default="before")

        hp_dropout_rate = hp.Float("dropout_rate_global", min_value=0.1, max_value=0.5, step=0.1, default=0.25)
        hp_num_conv_blocks = hp.Int("num_conv_blocks", min_value=1, max_value=4, step=1, default=3)
        
        current_filters = 0
        x = inputs

        for i in range(hp_num_conv_blocks):
            if i == 0:
                current_filters = hp.Choice("filters_start", values=[32, 64], default=32)
            else:
                current_filters = min(512, current_filters * 2)

            x = layers.Conv2D(filters=current_filters, kernel_size=FIXED_KERNEL_SIZE, activation=None)(x)

            if hp_use_batch_norm:
                if hp_bn_position == "before":
                    x = layers.BatchNormalization()(x)
                    x = layers.Activation("relu")(x)
                else:
                    x = layers.Activation("relu")(x)
                    x = layers.BatchNormalization()(x)
            else:
                x = layers.Activation("relu")(x)
                
            x = layers.MaxPooling2D(pool_size=(2, 2))(x)
        
        last_conv_filters = current_filters
        x = layers.Flatten(name="flatten")(x)

        hp_num_dense_layers = hp.Int("num_dense_layers", min_value=1, max_value=3, step=1, default=2)
        current_dense_units = 0

        for i in range(hp_num_dense_layers):
            hp_size_choice = hp.Choice("size_choice", values=["same", "half"], default="half")

            if hp_size_choice == "same":
                current_dense_units = max(MIN_DENSE_UNITS, last_conv_filters)
            else:
                current_dense_units = max(MIN_DENSE_UNITS, last_conv_filters // 2)

            x = layers.Dense(units=current_dense_units, activation="relu")(x)
            x = layers.Dropout(rate=hp_dropout_rate)(x)
        
        outputs = layers.Dense(NUM_AGE_CLASSES, activation="softmax", name="age_class_output")(x)
        model = Model(inputs=inputs, outputs=outputs)
        
        hp_learning_rate = hp.Choice("learning_rate", values=[0.0001, 0.001, 0.01], default=0.001)
        hp.Choice("batch_size", values=[32, 64, 128, 256], default=64)

        optimizer = tf.keras.optimizers.Adam(learning_rate=hp_learning_rate)
        model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"])

        return model

    # Idea taken from: https://github.com/keras-team/keras-tuner/issues/122#issuecomment-544648268
    def fit(self, hp, model, train_paths, train_labels, validation_data, **kwargs):
        batch_size = hp.Choice("batch_size", values=[32, 64, 128, 256], default=64)

        train_dataset = create_dataset(
            train_paths,
            train_labels,
            batch_size=batch_size,
            is_training=True
        )

        val_paths, val_labels = validation_data
        val_dataset = create_dataset(
            val_paths,
            val_labels,
            batch_size=batch_size,
            is_training=False
        )
        
        fit_kwargs = kwargs

        if self.use_class_weighting:
            print(f"Tuner trial: Applying class weights: {class_weight_dict}")
            fit_kwargs['class_weight'] = class_weight_dict
        else:
             print(f"Tuner trial: Not applying class weights.")

        return model.fit(
            train_dataset,
            validation_data=val_dataset,
            **fit_kwargs,
        )

# %%
tuner = kt.Hyperband(
    AgeHyperModel(),
    objective="val_accuracy",
    factor=3,
    directory="hyperparameter_tuning",
    project_name="ageclass_tuning",
)
# Out:
# I0000 00:00:1744479594.750537   17439 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20900 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# Reloading Tuner from hyperparameter_tuning/ageclass_tuning/tuner0.json

# %%
tuner.search(
    df_train_tune['Image_Path'],
    df_train_tune['Age_Class'],
    validation_data=(df_val_tune['Image_Path'], df_val_tune['Age_Class']),
    epochs=20,
    callbacks=[callbacks.EarlyStopping(patience=3, restore_best_weights=True)]
)

# %%
best_hps_list = tuner.get_best_hyperparameters(num_trials=1)
best_hps = best_hps_list[0]

print("Best Hyperparameters Found:")
for hp_name, hp_value in best_hps.values.items():
    print(f"{hp_name}: {hp_value}")

# %%
best_models_list = tuner.get_best_models(num_models=1)
best_model = best_models_list[0]
best_model.summary()

# %%
hps_filename_pkl = "best_hyperparameters.pkl"
with open(hps_filename_pkl, 'wb') as f:
    pickle.dump(best_hps, f)

# %%
with open("models/best_hyperparameters.pkl", 'rb') as f:
    loaded_best_hps = pickle.load(f)

print("Loaded HyperParameters Object:")
print(loaded_best_hps)
print("Values:", loaded_best_hps.values)

hypermodel_instance = tuner.hypermodel
reloaded_model_pkl = hypermodel_instance.build(loaded_best_hps)
reloaded_model_pkl.summary(line_length=100)
# Out:
# <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x7ff6a809b790>
# Values: {'use_batch_norm_global': False, 'bn_position': 'before', 'dropout_rate_global': 0.2, 'num_conv_blocks': 3, 'filters_start': 64, 'num_dense_layers': 3, 'size_choice': 'half', 'learning_rate': 0.0001, 'batch_size': 64, 'tuner/epochs': 12, 'tuner/initial_epoch': 4, 'tuner/bracket': 4, 'tuner/round': 2, 'tuner/trial_id': '0100'}
# Model: "model"
# ____________________________________________________________________________________________________
#  Layer (type)                                Output Shape                            Param #
# ====================================================================================================
#  input_image (InputLayer)                    [(None, 200, 200, 3)]                   0
#
#  conv2d (Conv2D)                             (None, 198, 198, 64)                    1792
#
#  activation (Activation)                     (None, 198, 198, 64)                    0
#
#  max_pooling2d (MaxPooling2D)                (None, 99, 99, 64)                      0
#
#  conv2d_1 (Conv2D)                           (None, 97, 97, 128)                     73856
#
#  activation_1 (Activation)                   (None, 97, 97, 128)                     0
#
#  max_pooling2d_1 (MaxPooling2D)              (None, 48, 48, 128)                     0
#
#  conv2d_2 (Conv2D)                           (None, 46, 46, 256)                     295168
#
#  activation_2 (Activation)                   (None, 46, 46, 256)                     0
#
#  max_pooling2d_2 (MaxPooling2D)              (None, 23, 23, 256)                     0
#
#  flatten (Flatten)                           (None, 135424)                          0
#
#  dense (Dense)                               (None, 128)                             17334400
#
#  dropout (Dropout)                           (None, 128)                             0
#
#  dense_1 (Dense)                             (None, 128)                             16512
#
#  dropout_1 (Dropout)                         (None, 128)                             0
#
#  dense_2 (Dense)                             (None, 128)                             16512
#
#  dropout_2 (Dropout)                         (None, 128)                             0
#
#  age_class_output (Dense)                    (None, 9)                               1161
#
# ====================================================================================================
# Total params: 17,739,401
# Trainable params: 17,739,401
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# 2025-04-12 15:38:22.569427: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-12 15:38:23.025425: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31088 MB memory:  -> device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:18:00.0, compute capability: 7.0

# %%
COMPILE_ARGS_BASE = {
    'optimizer': tf.keras.optimizers.Adam(learning_rate=loaded_best_hps.get('learning_rate')),
    'loss': 'sparse_categorical_crossentropy',
    'metrics': ['accuracy']
}

FIT_ARGS_BASE = {
    'epochs': 50,
    'batch_size': loaded_best_hps.get('batch_size'),
    'validation_split': 0.0,
    'verbose': 1,
    'callbacks': [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)]
}

N_SPLITS = 5
BATCH_SIZE = loaded_best_hps.get('batch_size')
AUTOTUNE = tf.data.AUTOTUNE

# %%
def run_cross_validation(
    X_paths,
    y_labels,
    best_hps,
    COMPILE_ARGS,
    FIT_ARGS,
    BATCH_SIZE,           
    IMG_HEIGHT=200,           
    IMG_WIDTH=200,          
    N_SPLITS=5,
    RANDOM_STATE=42,
    use_class_weighting=False,
    dataset_name="Dataset"
):
    skf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
    fold_no = 1
    fold_scores = {}
    fold_histories = []

    fit_class_weights = None
    local_fit_args = FIT_ARGS

    if use_class_weighting:
        classes = np.unique(y_labels)
        weights = compute_class_weight(
            class_weight='balanced',
            classes=classes,
            y=y_labels
        )
        fit_class_weights = dict(zip(classes, weights))
        local_fit_args['class_weight'] = fit_class_weights


    for train_index, val_index in skf.split(X_paths, y_labels):
        X_train_paths = X_paths[train_index]
        y_train_labels = y_labels[train_index]
        X_val_paths = X_paths[val_index]
        y_val_labels = y_labels[val_index]

        train_ds = create_dataset(
            X_train_paths, y_train_labels,
            batch_size=BATCH_SIZE,
            img_height=IMG_HEIGHT, img_width=IMG_WIDTH,
            is_training=True
        )
        val_ds = create_dataset(
            X_val_paths, y_val_labels,
            batch_size=BATCH_SIZE,
            img_height=IMG_HEIGHT, img_width=IMG_WIDTH,
            is_training=False
        )

        cv_model = hypermodel_instance.build(best_hps)
        cv_model.compile(**COMPILE_ARGS)

        history = cv_model.fit(
            train_ds,
            validation_data=val_ds,
            **local_fit_args
        )
        fold_histories.append(history)

        scores = cv_model.evaluate(val_ds, verbose=0)

        print(f"Fold {fold_no}: Evaluation Results ->")
        for metric_name, score in zip(cv_model.metrics_names, scores):
            print(f"  {metric_name}: {score:.4f}")
            if metric_name not in fold_scores:
                fold_scores[metric_name] = []
            fold_scores[metric_name].append(score)

        fold_no += 1

    print(f"----- Aggregating CV Results for: {dataset_name} -----")
    aggregated_scores = {}

    for metric_name, scores_list in fold_scores.items():
        avg = np.mean(scores_list)
        std = np.std(scores_list)
        aggregated_scores[metric_name] = {'mean': avg, 'std': std}

        print(f"Metric: {metric_name}")
        formatted_scores = [f"{s:.4f}" for s in scores_list]
        print(f"Scores per fold: {formatted_scores}")
        if 'accuracy' in metric_name.lower():
             print(f"  Average: {avg * 100:.2f}%")
             print(f"  Standard Deviation: {std * 100:.2f}%")
        else:
             print(f"  Average: {avg:.4f}")
             print(f"  Standard Deviation: {std:.4f}")
        print("-" * 30)

    return aggregated_scores

# %%
# Cross-Validation Base Dataset

X_base = np.array(df_train["Image_Path"])
y_base = np.array(df_train["Age_Class"])

base_cv_results = run_cross_validation(
    X_paths=X_base,
    y_labels=y_base,
    best_hps=loaded_best_hps,
    COMPILE_ARGS=COMPILE_ARGS_BASE,
    FIT_ARGS=FIT_ARGS_BASE,
    BATCH_SIZE=BATCH_SIZE,
    IMG_HEIGHT=200,
    IMG_WIDTH=200,
    use_class_weighting=False,
    dataset_name="Base Dataset"
)
# Out:
# Epoch 1/50
# 235/235 [==============================] - 13s 53ms/step - loss: 1.7530 - accuracy: 0.3628 - val_loss: 1.4502 - val_accuracy: 0.4426
# Epoch 2/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.4677 - accuracy: 0.4408 - val_loss: 1.3678 - val_accuracy: 0.4756
# Epoch 3/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.3664 - accuracy: 0.4716 - val_loss: 1.2986 - val_accuracy: 0.4931
# Epoch 4/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.2903 - accuracy: 0.4932 - val_loss: 1.2416 - val_accuracy: 0.5090
# Epoch 5/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.2200 - accuracy: 0.5150 - val_loss: 1.1956 - val_accuracy: 0.5226
# Epoch 6/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.1728 - accuracy: 0.5273 - val_loss: 1.1854 - val_accuracy: 0.5305
# Epoch 7/50
# 235/235 [==============================] - 12s 52ms/step - loss: 1.1220 - accuracy: 0.5479 - val_loss: 1.1420 - val_accuracy: 0.5366
# Epoch 8/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.0705 - accuracy: 0.5632 - val_loss: 1.1271 - val_accuracy: 0.5473
# Epoch 9/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.0264 - accuracy: 0.5789 - val_loss: 1.1559 - val_accuracy: 0.5438
# Epoch 10/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.9820 - accuracy: 0.5928 - val_loss: 1.1398 - val_accuracy: 0.5518
# Epoch 11/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.9370 - accuracy: 0.6091 - val_loss: 1.1119 - val_accuracy: 0.5555
# Epoch 12/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.9064 - accuracy: 0.6207 - val_loss: 1.1441 - val_accuracy: 0.5574
# Epoch 13/50
# 235/235 [==============================] - 12s 52ms/step - loss: 0.8573 - accuracy: 0.6405 - val_loss: 1.1775 - val_accuracy: 0.5457
# Epoch 14/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.8244 - accuracy: 0.6551 - val_loss: 1.1826 - val_accuracy: 0.5489
# Epoch 15/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.7827 - accuracy: 0.6739 - val_loss: 1.1898 - val_accuracy: 0.5507
# Epoch 16/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.7505 - accuracy: 0.6932 - val_loss: 1.2662 - val_accuracy: 0.5382
# Fold 1: Evaluation Results ->
#   loss: 1.1119
#   accuracy: 0.5555
# Epoch 1/50
# 235/235 [==============================] - 13s 53ms/step - loss: 1.7320 - accuracy: 0.3676 - val_loss: 1.4739 - val_accuracy: 0.4371
# Epoch 2/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.4605 - accuracy: 0.4406 - val_loss: 1.3572 - val_accuracy: 0.4758
# Epoch 3/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.3645 - accuracy: 0.4776 - val_loss: 1.2871 - val_accuracy: 0.5024
# Epoch 4/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.2888 - accuracy: 0.4959 - val_loss: 1.2362 - val_accuracy: 0.5157
# Epoch 5/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.2264 - accuracy: 0.5126 - val_loss: 1.2080 - val_accuracy: 0.5263
# Epoch 6/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.1683 - accuracy: 0.5335 - val_loss: 1.1863 - val_accuracy: 0.5295
# Epoch 7/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.1217 - accuracy: 0.5452 - val_loss: 1.1773 - val_accuracy: 0.5364
# Epoch 8/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.0779 - accuracy: 0.5619 - val_loss: 1.1783 - val_accuracy: 0.5372
# Epoch 9/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.0423 - accuracy: 0.5699 - val_loss: 1.1726 - val_accuracy: 0.5449
# Epoch 10/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.9955 - accuracy: 0.5939 - val_loss: 1.1889 - val_accuracy: 0.5242
# Epoch 11/50
# 235/235 [==============================] - 12s 52ms/step - loss: 0.9552 - accuracy: 0.6090 - val_loss: 1.1806 - val_accuracy: 0.5345
# Epoch 12/50
# 235/235 [==============================] - 12s 52ms/step - loss: 0.9247 - accuracy: 0.6200 - val_loss: 1.2082 - val_accuracy: 0.5287
# Epoch 13/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.8829 - accuracy: 0.6349 - val_loss: 1.2030 - val_accuracy: 0.5412
# Epoch 14/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.8437 - accuracy: 0.6531 - val_loss: 1.2261 - val_accuracy: 0.5404
# Fold 2: Evaluation Results ->
#   loss: 1.1726
#   accuracy: 0.5449
# Epoch 1/50
# 235/235 [==============================] - 13s 53ms/step - loss: 1.7297 - accuracy: 0.3755 - val_loss: 1.4736 - val_accuracy: 0.4360
# Epoch 2/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.4464 - accuracy: 0.4507 - val_loss: 1.3426 - val_accuracy: 0.4809
# Epoch 3/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.3271 - accuracy: 0.4874 - val_loss: 1.2351 - val_accuracy: 0.5101
# Epoch 4/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.2490 - accuracy: 0.5043 - val_loss: 1.1944 - val_accuracy: 0.5244
# Epoch 5/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.1874 - accuracy: 0.5269 - val_loss: 1.1505 - val_accuracy: 0.5369
# Epoch 6/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.1424 - accuracy: 0.5402 - val_loss: 1.1373 - val_accuracy: 0.5483
# Epoch 7/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.0821 - accuracy: 0.5574 - val_loss: 1.1206 - val_accuracy: 0.5523
# Epoch 8/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.0370 - accuracy: 0.5751 - val_loss: 1.1264 - val_accuracy: 0.5457
# Epoch 9/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.9875 - accuracy: 0.5983 - val_loss: 1.1295 - val_accuracy: 0.5467
# Epoch 10/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.9536 - accuracy: 0.6076 - val_loss: 1.1439 - val_accuracy: 0.5406
# Epoch 11/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.8996 - accuracy: 0.6309 - val_loss: 1.1486 - val_accuracy: 0.5414
# Epoch 12/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.8567 - accuracy: 0.6480 - val_loss: 1.1519 - val_accuracy: 0.5481
# Fold 3: Evaluation Results ->
#   loss: 1.1206
#   accuracy: 0.5523
# Epoch 1/50
# 235/235 [==============================] - 13s 54ms/step - loss: 1.7238 - accuracy: 0.3686 - val_loss: 1.4574 - val_accuracy: 0.4481
# Epoch 2/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.4334 - accuracy: 0.4557 - val_loss: 1.3214 - val_accuracy: 0.4895
# Epoch 3/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.3330 - accuracy: 0.4767 - val_loss: 1.2564 - val_accuracy: 0.4999
# Epoch 4/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.2587 - accuracy: 0.5015 - val_loss: 1.2180 - val_accuracy: 0.5177
# Epoch 5/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.1985 - accuracy: 0.5221 - val_loss: 1.1912 - val_accuracy: 0.5232
# Epoch 6/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.1480 - accuracy: 0.5361 - val_loss: 1.1873 - val_accuracy: 0.5256
# Epoch 7/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.1061 - accuracy: 0.5503 - val_loss: 1.1528 - val_accuracy: 0.5410
# Epoch 8/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.0604 - accuracy: 0.5630 - val_loss: 1.1387 - val_accuracy: 0.5493
# Epoch 9/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.0137 - accuracy: 0.5835 - val_loss: 1.1386 - val_accuracy: 0.5495
# Epoch 10/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.9761 - accuracy: 0.5961 - val_loss: 1.1289 - val_accuracy: 0.5511
# Epoch 11/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.9371 - accuracy: 0.6128 - val_loss: 1.1528 - val_accuracy: 0.5482
# Epoch 12/50
# 235/235 [==============================] - 12s 52ms/step - loss: 0.9091 - accuracy: 0.6214 - val_loss: 1.1537 - val_accuracy: 0.5519
# Epoch 13/50
# 235/235 [==============================] - 12s 52ms/step - loss: 0.8647 - accuracy: 0.6416 - val_loss: 1.1738 - val_accuracy: 0.5562
# Epoch 14/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.8257 - accuracy: 0.6555 - val_loss: 1.1996 - val_accuracy: 0.5381
# Epoch 15/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.7821 - accuracy: 0.6739 - val_loss: 1.2091 - val_accuracy: 0.5453
# Fold 4: Evaluation Results ->
#   loss: 1.1289
#   accuracy: 0.5511
# Epoch 1/50
# 235/235 [==============================] - 13s 53ms/step - loss: 1.6941 - accuracy: 0.3840 - val_loss: 1.4436 - val_accuracy: 0.4606
# Epoch 2/50
# 235/235 [==============================] - 12s 52ms/step - loss: 1.4238 - accuracy: 0.4589 - val_loss: 1.3515 - val_accuracy: 0.4935
# Epoch 3/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.3006 - accuracy: 0.4888 - val_loss: 1.2753 - val_accuracy: 0.5068
# Epoch 4/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.2335 - accuracy: 0.5070 - val_loss: 1.2056 - val_accuracy: 0.5270
# Epoch 5/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.1656 - accuracy: 0.5324 - val_loss: 1.1746 - val_accuracy: 0.5373
# Epoch 6/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.1187 - accuracy: 0.5429 - val_loss: 1.1407 - val_accuracy: 0.5426
# Epoch 7/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.0769 - accuracy: 0.5619 - val_loss: 1.1298 - val_accuracy: 0.5479
# Epoch 8/50
# 235/235 [==============================] - 12s 53ms/step - loss: 1.0358 - accuracy: 0.5781 - val_loss: 1.1162 - val_accuracy: 0.5490
# Epoch 9/50
# 235/235 [==============================] - 12s 52ms/step - loss: 0.9935 - accuracy: 0.5946 - val_loss: 1.1229 - val_accuracy: 0.5490
# Epoch 10/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.9473 - accuracy: 0.6061 - val_loss: 1.1313 - val_accuracy: 0.5506
# Epoch 11/50
# 235/235 [==============================] - 12s 52ms/step - loss: 0.9005 - accuracy: 0.6267 - val_loss: 1.1246 - val_accuracy: 0.5567
# Epoch 12/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.8645 - accuracy: 0.6458 - val_loss: 1.1701 - val_accuracy: 0.5572
# Epoch 13/50
# 235/235 [==============================] - 12s 53ms/step - loss: 0.8183 - accuracy: 0.6597 - val_loss: 1.1779 - val_accuracy: 0.5519
# Fold 5: Evaluation Results ->
#   loss: 1.1162
#   accuracy: 0.5490
# ----- Aggregating CV Results for: Base Dataset -----
# Metric: loss
# Scores per fold: ['1.1119', '1.1726', '1.1206', '1.1289', '1.1162']
#   Average: 1.1300
#   Standard Deviation: 0.0220
# ------------------------------
# Metric: accuracy
# Scores per fold: ['0.5555', '0.5449', '0.5523', '0.5511', '0.5490']
#   Average: 55.06%
#   Standard Deviation: 0.35%
# ------------------------------

# %%
# Training Base Dataset

reloaded_model_pkl.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=loaded_best_hps.get('learning_rate')),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

train_ds = create_dataset(
    df_train_tune['Image_Path'],
    df_train_tune['Age_Class'],
    batch_size=loaded_best_hps.get('batch_size'),
    is_training=True
)

val_ds = create_dataset(
    df_val_tune['Image_Path'],
    df_val_tune['Age_Class'],
    batch_size=loaded_best_hps.get('batch_size'),
    is_training=False
)

history = reloaded_model_pkl.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    batch_size=loaded_best_hps.get('batch_size'),
    callbacks=[callbacks.EarlyStopping(patience=3, restore_best_weights=True)],
    verbose=1
)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 13s 53ms/step - loss: 1.8509 - accuracy: 0.3359 - val_loss: 1.5575 - val_accuracy: 0.4384
# Epoch 2/100
# 235/235 [==============================] - 12s 53ms/step - loss: 1.5228 - accuracy: 0.4365 - val_loss: 1.3812 - val_accuracy: 0.4764
# Epoch 3/100
# 235/235 [==============================] - 12s 53ms/step - loss: 1.4032 - accuracy: 0.4682 - val_loss: 1.2968 - val_accuracy: 0.4952
# Epoch 4/100
# 235/235 [==============================] - 12s 53ms/step - loss: 1.3180 - accuracy: 0.4856 - val_loss: 1.2493 - val_accuracy: 0.5027
# Epoch 5/100
# 235/235 [==============================] - 12s 53ms/step - loss: 1.2469 - accuracy: 0.5072 - val_loss: 1.2005 - val_accuracy: 0.5074
# Epoch 6/100
# 235/235 [==============================] - 12s 53ms/step - loss: 1.1931 - accuracy: 0.5247 - val_loss: 1.2307 - val_accuracy: 0.5064
# Epoch 7/100
# 235/235 [==============================] - 12s 53ms/step - loss: 1.1442 - accuracy: 0.5457 - val_loss: 1.1587 - val_accuracy: 0.5226
# Epoch 8/100
# 235/235 [==============================] - 12s 53ms/step - loss: 1.0966 - accuracy: 0.5621 - val_loss: 1.1614 - val_accuracy: 0.5266
# Epoch 9/100
# 235/235 [==============================] - 12s 53ms/step - loss: 1.0425 - accuracy: 0.5762 - val_loss: 1.1472 - val_accuracy: 0.5398
# Epoch 10/100
# 235/235 [==============================] - 12s 53ms/step - loss: 1.0087 - accuracy: 0.5883 - val_loss: 1.1699 - val_accuracy: 0.5236
# Epoch 11/100
# 235/235 [==============================] - 12s 53ms/step - loss: 0.9698 - accuracy: 0.6035 - val_loss: 1.1558 - val_accuracy: 0.5393
# Epoch 12/100
# 235/235 [==============================] - 12s 53ms/step - loss: 0.9311 - accuracy: 0.6182 - val_loss: 1.1567 - val_accuracy: 0.5313

# %%
reloaded_model_pkl.save("base_model_trained.h5")

# %% [markdown]
# <h1 style="font-size:60px; line-height:1.2;">
#   Class Weighting Model
# </h1>

# %%
tuner_balanced = kt.Hyperband(
    AgeHyperModel(use_class_weighting=True),
    objective="val_accuracy",
    factor=3,
    directory="hyperparameter_tuning",
    project_name="ageclass_tuning_balanced",
)
# Out:
# Reloading Tuner from hyperparameter_tuning/ageclass_tuning_balanced/tuner0.json

# %%
tuner_balanced.search(
    df_train_tune['Image_Path'],
    df_train_tune['Age_Class'],
    validation_data=(df_val_tune['Image_Path'], df_val_tune['Age_Class']),
    epochs=20,
    callbacks=[callbacks.EarlyStopping(patience=3, restore_best_weights=True)]
)
# Out:
# Trial 254 Complete [00h 02m 58s]
# val_accuracy: 0.40042486786842346
#
# Best val_accuracy So Far: 0.5270844101905823
# Total elapsed time: 03h 10m 42s

# %%
best_hps_list_balanced = tuner_balanced.get_best_hyperparameters(num_trials=1)
best_hps_balanced = best_hps_list_balanced[0]

print("--- Best Hyperparameters Found ---")
for hp_name, hp_value in best_hps_balanced.values.items():
    print(f"{hp_name}: {hp_value}")
# Out:
# --- Best Hyperparameters Found ---
# use_batch_norm_global: False
# bn_position: after
# dropout_rate_global: 0.5
# num_conv_blocks: 4
# filters_start: 64
# num_dense_layers: 3
# size_choice: same
# learning_rate: 0.0001
# batch_size: 64
# tuner/epochs: 34
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0

# %%
best_models_list_balanced = tuner_balanced.get_best_models(num_models=1)
best_model_balanced = best_models_list_balanced[0]
best_model_balanced.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_image (InputLayer)    [(None, 200, 200, 3)]     0
#
#  conv2d (Conv2D)             (None, 198, 198, 64)      1792
#
#  activation (Activation)     (None, 198, 198, 64)      0
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 128)       73856
#
#  activation_1 (Activation)   (None, 97, 97, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 256)       295168
#
#  activation_2 (Activation)   (None, 46, 46, 256)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 256)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 512)       1180160
#
#  activation_3 (Activation)   (None, 21, 21, 512)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 512)      0
#  2D)
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 512)               26214912
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  age_class_output (Dense)    (None, 9)                 4617
#
# =================================================================
# Total params: 28,295,817
# Trainable params: 28,295,817
# Non-trainable params: 0
# _________________________________________________________________

# %%
hps_filename_pkl_balanced = "best_hyperparameters_balanced.pkl"
with open(hps_filename_pkl_balanced, 'wb') as f:
    pickle.dump(best_hps_balanced, f)

# %%
with open("models/best_hyperparameters_balanced.pkl", 'rb') as f:
    loaded_best_hps_balanced = pickle.load(f)

print("Loaded HyperParameters Object:")
print(loaded_best_hps_balanced)
print("Values:", loaded_best_hps_balanced.values)

hypermodel_instance = tuner_balanced.hypermodel
reloaded_model_pkl_balanced = hypermodel_instance.build(loaded_best_hps_balanced)
reloaded_model_pkl_balanced.summary(line_length=100)
# Out:
# Loaded HyperParameters Object:
# <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x7ff59469ee00>
# Values: {'use_batch_norm_global': False, 'bn_position': 'after', 'dropout_rate_global': 0.5, 'num_conv_blocks': 4, 'filters_start': 64, 'num_dense_layers': 3, 'size_choice': 'same', 'learning_rate': 0.0001, 'batch_size': 64, 'tuner/epochs': 34, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}
# Model successfully rebuilt from loaded hyperparameters object:
# Model: "model"
# ____________________________________________________________________________________________________
#  Layer (type)                                Output Shape                            Param #
# ====================================================================================================
#  input_image (InputLayer)                    [(None, 200, 200, 3)]                   0
#
#  conv2d (Conv2D)                             (None, 198, 198, 64)                    1792
#
#  activation (Activation)                     (None, 198, 198, 64)                    0
#
#  max_pooling2d (MaxPooling2D)                (None, 99, 99, 64)                      0
#
#  conv2d_1 (Conv2D)                           (None, 97, 97, 128)                     73856
#
#  activation_1 (Activation)                   (None, 97, 97, 128)                     0
#
#  max_pooling2d_1 (MaxPooling2D)              (None, 48, 48, 128)                     0
#
#  conv2d_2 (Conv2D)                           (None, 46, 46, 256)                     295168
#
#  activation_2 (Activation)                   (None, 46, 46, 256)                     0
#
#  max_pooling2d_2 (MaxPooling2D)              (None, 23, 23, 256)                     0
#
#  conv2d_3 (Conv2D)                           (None, 21, 21, 512)                     1180160
#
#  activation_3 (Activation)                   (None, 21, 21, 512)                     0
#
#  max_pooling2d_3 (MaxPooling2D)              (None, 10, 10, 512)                     0
#
#  flatten (Flatten)                           (None, 51200)                           0
#
#  dense (Dense)                               (None, 512)                             26214912
#
#  dropout (Dropout)                           (None, 512)                             0
#
#  dense_1 (Dense)                             (None, 512)                             262656
#
#  dropout_1 (Dropout)                         (None, 512)                             0
#
#  dense_2 (Dense)                             (None, 512)                             262656
#
#  dropout_2 (Dropout)                         (None, 512)                             0
#
#  age_class_output (Dense)                    (None, 9)                               4617
#
# ====================================================================================================
# Total params: 28,295,817
# Trainable params: 28,295,817
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
# Cross-Validation Class Weighting Dataset

COMPILE_ARGS_BALANCED = {
    'optimizer': tf.keras.optimizers.Adam(learning_rate=loaded_best_hps_balanced.get('learning_rate')),
    'loss': 'sparse_categorical_crossentropy',
    'metrics': ['accuracy']
}

FIT_ARGS_BALANCED = {
    'epochs': 50,
    'batch_size': loaded_best_hps_balanced.get('batch_size'),
    'validation_split': 0.0,
    'verbose': 1,
    'callbacks': [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)]
}

N_SPLITS = 5
BATCH_SIZE = loaded_best_hps_balanced.get('batch_size')
AUTOTUNE = tf.data.AUTOTUNE

X_base = np.array(df_train["Image_Path"])
y_base = np.array(df_train["Age_Class"])

base_cv_results_balanced = run_cross_validation(
    X_paths=X_base,
    y_labels=y_base,
    best_hps=loaded_best_hps_balanced,
    COMPILE_ARGS=COMPILE_ARGS_BALANCED,
    FIT_ARGS=FIT_ARGS_BALANCED,
    BATCH_SIZE=BATCH_SIZE,
    IMG_HEIGHT=200,
    IMG_WIDTH=200,
    use_class_weighting=True,
    dataset_name="Dataset Class Weighting"
)
# Out:
# Epoch 1/50
# 235/235 [==============================] - 16s 63ms/step - loss: 2.1996 - accuracy: 0.1012 - val_loss: 2.1944 - val_accuracy: 0.1275
# Epoch 2/50
# 235/235 [==============================] - 15s 62ms/step - loss: 2.1321 - accuracy: 0.1816 - val_loss: 1.8566 - val_accuracy: 0.3279
# Epoch 3/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.8147 - accuracy: 0.3095 - val_loss: 1.5735 - val_accuracy: 0.3901
# Epoch 4/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.6264 - accuracy: 0.3551 - val_loss: 1.4845 - val_accuracy: 0.4063
# Epoch 5/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.5206 - accuracy: 0.3887 - val_loss: 1.3703 - val_accuracy: 0.4538
# Epoch 6/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.4431 - accuracy: 0.4103 - val_loss: 1.3565 - val_accuracy: 0.4644
# Epoch 7/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.3811 - accuracy: 0.4301 - val_loss: 1.3150 - val_accuracy: 0.4827
# Epoch 8/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.3201 - accuracy: 0.4536 - val_loss: 1.3039 - val_accuracy: 0.4867
# Epoch 9/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.2648 - accuracy: 0.4719 - val_loss: 1.2604 - val_accuracy: 0.5016
# Epoch 10/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.2326 - accuracy: 0.4771 - val_loss: 1.2279 - val_accuracy: 0.5093
# Epoch 11/50
# 235/235 [==============================] - 14s 62ms/step - loss: 1.1682 - accuracy: 0.4901 - val_loss: 1.2454 - val_accuracy: 0.4766
# Epoch 12/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.1230 - accuracy: 0.5011 - val_loss: 1.1825 - val_accuracy: 0.5207
# Epoch 13/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.0721 - accuracy: 0.5211 - val_loss: 1.1718 - val_accuracy: 0.5263
# Epoch 14/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.0272 - accuracy: 0.5340 - val_loss: 1.1541 - val_accuracy: 0.5252
# Epoch 15/50
# 235/235 [==============================] - 14s 61ms/step - loss: 0.9814 - accuracy: 0.5424 - val_loss: 1.1921 - val_accuracy: 0.5003
# Epoch 16/50
# 235/235 [==============================] - 14s 61ms/step - loss: 0.9361 - accuracy: 0.5568 - val_loss: 1.2111 - val_accuracy: 0.5011
# Epoch 17/50
# 235/235 [==============================] - 14s 62ms/step - loss: 0.8861 - accuracy: 0.5725 - val_loss: 1.1813 - val_accuracy: 0.5157
# Epoch 18/50
# 235/235 [==============================] - 14s 62ms/step - loss: 0.8525 - accuracy: 0.5850 - val_loss: 1.1989 - val_accuracy: 0.5138
# Epoch 19/50
# 235/235 [==============================] - 15s 62ms/step - loss: 0.7985 - accuracy: 0.5998 - val_loss: 1.2225 - val_accuracy: 0.5271
# Fold 1: Evaluation Results ->
#   loss: 1.1541
#   accuracy: 0.5252
# Epoch 1/50
# 235/235 [==============================] - 15s 63ms/step - loss: 2.1631 - accuracy: 0.1813 - val_loss: 1.8266 - val_accuracy: 0.3787
# Epoch 2/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.8276 - accuracy: 0.3203 - val_loss: 1.6625 - val_accuracy: 0.3486
# Epoch 3/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.6106 - accuracy: 0.3677 - val_loss: 1.4671 - val_accuracy: 0.4357
# Epoch 4/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.4971 - accuracy: 0.3985 - val_loss: 1.4030 - val_accuracy: 0.4511
# Epoch 5/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.4127 - accuracy: 0.4184 - val_loss: 1.3248 - val_accuracy: 0.4819
# Epoch 6/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.3545 - accuracy: 0.4363 - val_loss: 1.2963 - val_accuracy: 0.4936
# Epoch 7/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.2959 - accuracy: 0.4509 - val_loss: 1.2641 - val_accuracy: 0.4987
# Epoch 8/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.2483 - accuracy: 0.4670 - val_loss: 1.2623 - val_accuracy: 0.4912
# Epoch 9/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.1972 - accuracy: 0.4826 - val_loss: 1.2127 - val_accuracy: 0.5146
# Epoch 10/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.1596 - accuracy: 0.4920 - val_loss: 1.1721 - val_accuracy: 0.5255
# Epoch 11/50
# 235/235 [==============================] - 14s 62ms/step - loss: 1.0971 - accuracy: 0.5134 - val_loss: 1.1837 - val_accuracy: 0.5223
# Epoch 12/50
# 235/235 [==============================] - 14s 61ms/step - loss: 1.0517 - accuracy: 0.5219 - val_loss: 1.1752 - val_accuracy: 0.5268
# Epoch 13/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.0099 - accuracy: 0.5412 - val_loss: 1.1599 - val_accuracy: 0.5377
# Epoch 14/50
# 235/235 [==============================] - 14s 61ms/step - loss: 0.9726 - accuracy: 0.5435 - val_loss: 1.1625 - val_accuracy: 0.5358
# Epoch 15/50
# 235/235 [==============================] - 14s 61ms/step - loss: 0.9431 - accuracy: 0.5540 - val_loss: 1.1681 - val_accuracy: 0.5324
# Epoch 16/50
# 235/235 [==============================] - 15s 62ms/step - loss: 0.9015 - accuracy: 0.5622 - val_loss: 1.1514 - val_accuracy: 0.5478
# Epoch 17/50
# 235/235 [==============================] - 14s 62ms/step - loss: 0.8642 - accuracy: 0.5729 - val_loss: 1.2135 - val_accuracy: 0.5284
# Epoch 18/50
# 235/235 [==============================] - 15s 62ms/step - loss: 0.8277 - accuracy: 0.5874 - val_loss: 1.1947 - val_accuracy: 0.5345
# Epoch 19/50
# 235/235 [==============================] - 14s 62ms/step - loss: 0.7875 - accuracy: 0.6009 - val_loss: 1.2293 - val_accuracy: 0.5337
# Epoch 20/50
# 235/235 [==============================] - 14s 61ms/step - loss: 0.7456 - accuracy: 0.6110 - val_loss: 1.2125 - val_accuracy: 0.5441
# Epoch 21/50
# 235/235 [==============================] - 15s 62ms/step - loss: 0.7237 - accuracy: 0.6154 - val_loss: 1.2632 - val_accuracy: 0.5377
# Fold 2: Evaluation Results ->
#   loss: 1.1514
#   accuracy: 0.5478
# Epoch 1/50
# 235/235 [==============================] - 15s 63ms/step - loss: 2.1995 - accuracy: 0.0930 - val_loss: 2.1983 - val_accuracy: 0.0215
# Epoch 2/50
# 235/235 [==============================] - 14s 61ms/step - loss: 2.1980 - accuracy: 0.0882 - val_loss: 2.1972 - val_accuracy: 0.0215
# Epoch 3/50
# 235/235 [==============================] - 14s 62ms/step - loss: 2.1949 - accuracy: 0.1134 - val_loss: 2.1146 - val_accuracy: 0.3125
# Epoch 4/50
# 235/235 [==============================] - 14s 62ms/step - loss: 2.0471 - accuracy: 0.2735 - val_loss: 1.7426 - val_accuracy: 0.3484
# Epoch 5/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.7406 - accuracy: 0.3279 - val_loss: 1.5469 - val_accuracy: 0.4018
# Epoch 6/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.5804 - accuracy: 0.3699 - val_loss: 1.4612 - val_accuracy: 0.4262
# Epoch 7/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.4810 - accuracy: 0.3991 - val_loss: 1.3072 - val_accuracy: 0.4700
# Epoch 8/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.4163 - accuracy: 0.4189 - val_loss: 1.2941 - val_accuracy: 0.4729
# Epoch 9/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.3528 - accuracy: 0.4390 - val_loss: 1.2475 - val_accuracy: 0.4867
# Epoch 10/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.3035 - accuracy: 0.4511 - val_loss: 1.2339 - val_accuracy: 0.4910
# Epoch 11/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.2577 - accuracy: 0.4685 - val_loss: 1.2048 - val_accuracy: 0.5029
# Epoch 12/50
# 235/235 [==============================] - 14s 61ms/step - loss: 1.2158 - accuracy: 0.4796 - val_loss: 1.2146 - val_accuracy: 0.5029
# Epoch 13/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.1768 - accuracy: 0.4916 - val_loss: 1.2026 - val_accuracy: 0.4997
# Epoch 14/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.1324 - accuracy: 0.5025 - val_loss: 1.1650 - val_accuracy: 0.5154
# Epoch 15/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.0938 - accuracy: 0.5117 - val_loss: 1.1374 - val_accuracy: 0.5356
# Epoch 16/50
# 235/235 [==============================] - 14s 62ms/step - loss: 1.0572 - accuracy: 0.5198 - val_loss: 1.1743 - val_accuracy: 0.5167
# Epoch 17/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.0164 - accuracy: 0.5363 - val_loss: 1.2216 - val_accuracy: 0.5003
# Epoch 18/50
# 235/235 [==============================] - 14s 62ms/step - loss: 0.9827 - accuracy: 0.5363 - val_loss: 1.1581 - val_accuracy: 0.5204
# Epoch 19/50
# 235/235 [==============================] - 15s 62ms/step - loss: 0.9576 - accuracy: 0.5574 - val_loss: 1.2117 - val_accuracy: 0.5029
# Epoch 20/50
# 235/235 [==============================] - 15s 62ms/step - loss: 0.9051 - accuracy: 0.5634 - val_loss: 1.2084 - val_accuracy: 0.5090
# Fold 3: Evaluation Results ->
#   loss: 1.1374
#   accuracy: 0.5356
# Epoch 1/50
# 235/235 [==============================] - 15s 63ms/step - loss: 2.1990 - accuracy: 0.0943 - val_loss: 2.1550 - val_accuracy: 0.1278
# Epoch 2/50
# 235/235 [==============================] - 24s 101ms/step - loss: 2.1879 - accuracy: 0.1688 - val_loss: 2.0763 - val_accuracy: 0.2675
# Epoch 3/50
# 235/235 [==============================] - 15s 63ms/step - loss: 2.0546 - accuracy: 0.2814 - val_loss: 1.6491 - val_accuracy: 0.3777
# Epoch 4/50
# 235/235 [==============================] - 14s 62ms/step - loss: 1.7102 - accuracy: 0.3475 - val_loss: 1.5844 - val_accuracy: 0.3950
# Epoch 5/50
# 235/235 [==============================] - 14s 62ms/step - loss: 1.5680 - accuracy: 0.3763 - val_loss: 1.4533 - val_accuracy: 0.4284
# Epoch 6/50
# 235/235 [==============================] - 14s 61ms/step - loss: 1.4697 - accuracy: 0.4045 - val_loss: 1.4824 - val_accuracy: 0.3880
# Epoch 7/50
# 235/235 [==============================] - 14s 61ms/step - loss: 1.4157 - accuracy: 0.4162 - val_loss: 1.4688 - val_accuracy: 0.3987
# Epoch 8/50
# 235/235 [==============================] - 14s 62ms/step - loss: 1.3619 - accuracy: 0.4311 - val_loss: 1.3830 - val_accuracy: 0.4396
# Epoch 9/50
# 235/235 [==============================] - 14s 61ms/step - loss: 1.3134 - accuracy: 0.4497 - val_loss: 1.4053 - val_accuracy: 0.4242
# Epoch 10/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.2674 - accuracy: 0.4675 - val_loss: 1.3219 - val_accuracy: 0.4600
# Epoch 11/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.2192 - accuracy: 0.4795 - val_loss: 1.2657 - val_accuracy: 0.4858
# Epoch 12/50
# 235/235 [==============================] - 14s 61ms/step - loss: 1.1823 - accuracy: 0.4908 - val_loss: 1.3225 - val_accuracy: 0.4566
# Epoch 13/50
# 235/235 [==============================] - 14s 61ms/step - loss: 1.1335 - accuracy: 0.4998 - val_loss: 1.3170 - val_accuracy: 0.4622
# Epoch 14/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.1065 - accuracy: 0.5085 - val_loss: 1.2237 - val_accuracy: 0.4969
# Epoch 15/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.0685 - accuracy: 0.5247 - val_loss: 1.2186 - val_accuracy: 0.5031
# Epoch 16/50
# 235/235 [==============================] - 14s 61ms/step - loss: 1.0244 - accuracy: 0.5311 - val_loss: 1.2247 - val_accuracy: 0.4988
# Epoch 17/50
# 235/235 [==============================] - 14s 62ms/step - loss: 0.9872 - accuracy: 0.5392 - val_loss: 1.2275 - val_accuracy: 0.5057
# Epoch 18/50
# 235/235 [==============================] - 15s 62ms/step - loss: 0.9524 - accuracy: 0.5559 - val_loss: 1.2105 - val_accuracy: 0.5084
# Epoch 19/50
# 235/235 [==============================] - 14s 62ms/step - loss: 0.9232 - accuracy: 0.5622 - val_loss: 1.2241 - val_accuracy: 0.5222
# Epoch 20/50
# 235/235 [==============================] - 14s 61ms/step - loss: 0.8839 - accuracy: 0.5767 - val_loss: 1.2345 - val_accuracy: 0.5129
# Epoch 21/50
# 235/235 [==============================] - 14s 61ms/step - loss: 0.8620 - accuracy: 0.5779 - val_loss: 1.2317 - val_accuracy: 0.5169
# Epoch 22/50
# 235/235 [==============================] - 14s 61ms/step - loss: 0.8356 - accuracy: 0.5877 - val_loss: 1.2151 - val_accuracy: 0.5256
# Epoch 23/50
# 235/235 [==============================] - 15s 62ms/step - loss: 0.8003 - accuracy: 0.5930 - val_loss: 1.2658 - val_accuracy: 0.5309
# Fold 4: Evaluation Results ->
#   loss: 1.2105
#   accuracy: 0.5084
# Epoch 1/50
# 235/235 [==============================] - 15s 62ms/step - loss: 2.1993 - accuracy: 0.0937 - val_loss: 2.1956 - val_accuracy: 0.1275
# Epoch 2/50
# 235/235 [==============================] - 14s 61ms/step - loss: 2.1980 - accuracy: 0.0975 - val_loss: 2.1972 - val_accuracy: 0.1291
# Epoch 3/50
# 235/235 [==============================] - 14s 61ms/step - loss: 2.1977 - accuracy: 0.1074 - val_loss: 2.1960 - val_accuracy: 0.1275
# Epoch 4/50
# 235/235 [==============================] - 14s 61ms/step - loss: 2.1852 - accuracy: 0.1307 - val_loss: 2.0537 - val_accuracy: 0.2688
# Epoch 5/50
# 235/235 [==============================] - 14s 62ms/step - loss: 1.9453 - accuracy: 0.2923 - val_loss: 1.6607 - val_accuracy: 0.3692
# Epoch 6/50
# 235/235 [==============================] - 14s 62ms/step - loss: 1.6758 - accuracy: 0.3418 - val_loss: 1.5502 - val_accuracy: 0.3788
# Epoch 7/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.5236 - accuracy: 0.3883 - val_loss: 1.4284 - val_accuracy: 0.4274
# Epoch 8/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.4511 - accuracy: 0.4042 - val_loss: 1.3533 - val_accuracy: 0.4457
# Epoch 9/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.3909 - accuracy: 0.4258 - val_loss: 1.3209 - val_accuracy: 0.4754
# Epoch 10/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.3388 - accuracy: 0.4431 - val_loss: 1.3168 - val_accuracy: 0.4571
# Epoch 11/50
# 235/235 [==============================] - 14s 61ms/step - loss: 1.2871 - accuracy: 0.4564 - val_loss: 1.4011 - val_accuracy: 0.4125
# Epoch 12/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.2295 - accuracy: 0.4719 - val_loss: 1.3076 - val_accuracy: 0.4542
# Epoch 13/50
# 235/235 [==============================] - 15s 62ms/step - loss: 1.1921 - accuracy: 0.4834 - val_loss: 1.2463 - val_accuracy: 0.4770
# Epoch 14/50
# 235/235 [==============================] - 14s 62ms/step - loss: 1.1441 - accuracy: 0.4951 - val_loss: 1.2726 - val_accuracy: 0.4643
# Epoch 15/50
# 235/235 [==============================] - 14s 62ms/step - loss: 1.1040 - accuracy: 0.5112 - val_loss: 1.3106 - val_accuracy: 0.4507
# Epoch 16/50
# 235/235 [==============================] - 14s 62ms/step - loss: 1.0675 - accuracy: 0.5163 - val_loss: 1.3197 - val_accuracy: 0.4433
# Epoch 17/50
# 235/235 [==============================] - 14s 62ms/step - loss: 1.0233 - accuracy: 0.5287 - val_loss: 1.2984 - val_accuracy: 0.4465
# Epoch 18/50
# 235/235 [==============================] - 15s 62ms/step - loss: 0.9900 - accuracy: 0.5370 - val_loss: 1.2297 - val_accuracy: 0.4869
# Epoch 19/50
# 235/235 [==============================] - 15s 62ms/step - loss: 0.9506 - accuracy: 0.5485 - val_loss: 1.2086 - val_accuracy: 0.5009
# Epoch 20/50
# 235/235 [==============================] - 14s 62ms/step - loss: 0.9047 - accuracy: 0.5578 - val_loss: 1.2148 - val_accuracy: 0.4959
# Epoch 21/50
# 235/235 [==============================] - 14s 62ms/step - loss: 0.8772 - accuracy: 0.5700 - val_loss: 1.2427 - val_accuracy: 0.4954
# Epoch 22/50
# 235/235 [==============================] - 14s 62ms/step - loss: 0.8216 - accuracy: 0.5840 - val_loss: 1.2754 - val_accuracy: 0.4914
# Epoch 23/50
# 235/235 [==============================] - 15s 62ms/step - loss: 0.7861 - accuracy: 0.6021 - val_loss: 1.2682 - val_accuracy: 0.4876
# Epoch 24/50
# 235/235 [==============================] - 15s 62ms/step - loss: 0.7825 - accuracy: 0.6084 - val_loss: 1.2871 - val_accuracy: 0.4863
# Fold 5: Evaluation Results ->
#   loss: 1.2086
#   accuracy: 0.5009
# ----- Aggregating CV Results for: Dataset Class Weighting -----
# Metric: loss
# Scores per fold: ['1.1541', '1.1514', '1.1374', '1.2105', '1.2086']
#   Average: 1.1724
#   Standard Deviation: 0.0309
# ------------------------------
# Metric: accuracy
# Scores per fold: ['0.5252', '0.5478', '0.5356', '0.5084', '0.5009']
#   Average: 52.36%
#   Standard Deviation: 1.72%
# ------------------------------

# %%
# Training Class Weighting Dataset

reloaded_model_pkl_balanced.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=loaded_best_hps_balanced.get('learning_rate')),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

train_ds_balanced = create_dataset(
    df_train_tune['Image_Path'],
    df_train_tune['Age_Class'],
    batch_size=loaded_best_hps_balanced.get('batch_size'),
    is_training=True
)

val_ds_balanced = create_dataset(
    df_val_tune['Image_Path'],
    df_val_tune['Age_Class'],
    batch_size=loaded_best_hps_balanced.get('batch_size'),
    is_training=False
)

history_balanced = reloaded_model_pkl_balanced.fit(
    train_ds_balanced,
    validation_data=val_ds_balanced,
    epochs=100,
    batch_size=loaded_best_hps_balanced.get('batch_size'),
    class_weight=class_weight_dict,
    callbacks=[callbacks.EarlyStopping(patience=3, restore_best_weights=True)],
    verbose=1
)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 15s 62ms/step - loss: 1.0647 - accuracy: 0.5864 - val_loss: 1.2175 - val_accuracy: 0.5112
# Epoch 2/100
# 235/235 [==============================] - 14s 61ms/step - loss: 1.0554 - accuracy: 0.5741 - val_loss: 1.2244 - val_accuracy: 0.4995
# Epoch 3/100
# 235/235 [==============================] - 14s 61ms/step - loss: 1.0238 - accuracy: 0.5846 - val_loss: 1.2284 - val_accuracy: 0.5042
# Epoch 4/100
# 235/235 [==============================] - 14s 61ms/step - loss: 1.0116 - accuracy: 0.5858 - val_loss: 1.2342 - val_accuracy: 0.5011

# %%
reloaded_model_pkl_balanced.save("class_weight_model_trained.h5")
